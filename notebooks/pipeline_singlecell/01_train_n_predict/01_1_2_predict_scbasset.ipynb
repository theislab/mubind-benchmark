# %% [markdown]
# ### List datasets that will be used for training with scBasset

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import scbasset
# Out:
# 2024-06-14 09:59:05.194112: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-14 09:59:05.244288: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-14 09:59:05.246314: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-06-14 09:59:05.246324: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-06-14 09:59:05.557714: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-06-14 09:59:05.557748: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-06-14 09:59:05.557751: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
cd ~/workspace/theislab/mubind-pipeline/notebooks/pipeline
# Out:
# /home/ilibarra/workspace/theislab/mubind-pipeline/notebooks/pipeline

# %%
# read scbasset
import tensorflow as tf
import scanpy as sc
from scbasset.utils import *
from scbasset.basenji_utils import *
from scbasset.utils import *
import pandas as pd
import glob
import os
import anndata
import pickle
import datetime

# %% [markdown]
# ### Load scBasset models and score with them

# %%
overwrite = False

# %%
# rootdir = '/mnt/f/workspace/theislab/mubind/data/*/*/scbasset_output/obs*/*/*/*'
rootdir = '/home/ilibarra/workspace/theislab/mubind/data/*/*/scbasset_output/obs*/*/*/*'

df = []

for p in glob.glob(rootdir):

    # print(p)
    res = []
    if not os.path.exists(p):
        continue
    if not 'best_model.h5' in p:
        continue

    print(p)
    # continue
    # assert False
    runtime_path = p.replace('best_model.h5', 'running_time.pkl')
    time_diff = pickle.load(open(runtime_path, 'rb')) if os.path.exists(runtime_path) else None

    # print(time_diff, type(time_diff))
    if not isinstance(time_diff, datetime.timedelta):
        # print('time log not ok....skip')
        continue

    # continue

    scores_path = p.replace('.h5', '_scores.csv')
    print(os.path.exists(scores_path), scores_path)
    if os.path.exists(scores_path) and not overwrite:
        # print('here...')
        df2 = pd.read_csv(scores_path, index_col=0)
        df2['n_obs'] = scores_path.split('/')[-4].replace('obs', '').split('_')[0]
        # print(time_diff)
        df2['time'] = time_diff.total_seconds()
        df.append(df2)
        continue

    os.makedirs("results", exist_ok=True)

    n_obs = p.split('/')[-4].split('_')[0] # .replace('obs', '')
    dataset_name = p.split('/')[-7]
    feature_selection_rule = p.split('/')[-6]
    loss_key = p.split('/')[-3]

    print(n_obs, dataset_name, feature_selection_rule, loss_key)
    
    fold_key = p.split('/')[-2]
    ad_path = os.path.join(os.path.dirname(p),
                           '../../../../scbasset_input/%s/%s/ad.h5ad' % (n_obs, fold_key))
    seqs_path = os.path.join(os.path.dirname(p),
                                '../../../../scbasset_input/%s/%s/all_seqs.h5' % (n_obs, fold_key))
    train_seqs = os.path.join(os.path.dirname(p),
                                '../../../../scbasset_input/%s/%s/train_seqs.h5' % (n_obs, fold_key))
    val_seqs = os.path.join(os.path.dirname(p),
                                '../../../../scbasset_input/%s/%s/val_seqs.h5' % (n_obs, fold_key))
    test_seqs = os.path.join(os.path.dirname(p),
                                '../../../../scbasset_input/%s/%s/test_seqs.h5' % (n_obs, fold_key))
    splits_path = os.path.join(os.path.dirname(p),
                                '../../../../scbasset_input/%s/%s/splits.h5' % (n_obs, fold_key))
    print(os.path.exists(ad_path), ad_path)

    # read h5ad file
    ad = anndata.read_h5ad(ad_path)

    # load model
    model = make_model(32, ad.shape[0], show_summary=False)
    model.load_weights(p)

    # since imputation generates a dense cell by peak matrix as output.
    # it won't scale to very large dataset due to memory issue.
    # predict scores
    print('get sequences scores')
    all_seqs = seqs_path # from the preprocess step
    # make tesorflow dataset to feed into model
    m = ad.X.tocoo().transpose().tocsr()
    n_cells = ad.shape[0]
    all_ds = tf.data.Dataset.from_generator(
        generator(all_seqs, m), 
        output_signature=(
                tf.TensorSpec(shape=(1344,4), dtype=tf.int8),
                tf.TensorSpec(shape=(n_cells), dtype=tf.int8),
        )
    ).batch(128).prefetch(tf.data.AUTOTUNE)
    
    # Y_impute = imputation_Y_normalize(all_ds, model)
    Y_pred = model.predict(all_ds)
    Y_pred = Y_pred.T

    Y_true = ad.X.A

    # convert to csr matrix
    import h5py
    with h5py.File(splits_path, 'r') as hf:
        train_ids = hf['train_ids'][:]
        val_ids = hf['val_ids'][:]
        test_ids = hf['test_ids'][:]

    import matplotlib.pyplot as plt
    from sklearn.metrics import r2_score, roc_auc_score
    from sklearn.metrics import average_precision_score
    # plt.scatter(Y_true.A.flatten(), Y_pred.flatten())
    from sklearn.preprocessing import LabelBinarizer
    import sklearn


    for next_ids, label in zip([train_ids, val_ids, test_ids], ['train', 'val', 'test']):

        # roc auc
        Y_true_roc = np.where(Y_true[:,next_ids] > 0, 1, Y_true[:,next_ids])
        
        roc_auc, pr_auc, pr_auc_multi, roc_auc_multi = np.nan, np.nan, np.nan, np.nan
        # assert False
        try:
            roc_auc = roc_auc_score(Y_true_roc.flatten(), Y_pred[:,next_ids].flatten())
            pr_auc = average_precision_score(Y_true_roc.flatten(), Y_pred[:,next_ids].flatten())

            y_flatten = Y_true_roc.flatten()
            label_binarizer = LabelBinarizer().fit(y_flatten)
            y_onehot_test = label_binarizer.transform(y_flatten)
            pred_onehot = label_binarizer.transform(Y_pred[:,next_ids].flatten().round())
            # y_onehot_test.shape  # (n_samples, n_classes)
            
            pr_auc_multi= sklearn.metrics.average_precision_score(y_onehot_test, pred_onehot)
            roc_auc_multi= roc_auc_score(y_onehot_test, pred_onehot)

        except:
            print('problem while calculating PR/AUC (maybe full zero mats)')

        res.append([dataset_name, feature_selection_rule, loss_key, label, 'roc_auc', roc_auc, p, fold_key])        
        res.append([dataset_name, feature_selection_rule, loss_key, label, 'roc_auc_multi', roc_auc_multi, p, fold_key])        
        res.append([dataset_name, feature_selection_rule, loss_key, label, 'pr_auc', pr_auc, p, fold_key])        
        res.append([dataset_name, feature_selection_rule, loss_key, label, 'pr_auc_multi', pr_auc_multi, p, fold_key])        

        # assert False

        r2 = r2_score(Y_true[:,next_ids].flatten(), Y_pred[:,next_ids].flatten())
        res.append([dataset_name, feature_selection_rule, loss_key, label, 'r2', r2, p, fold_key])        
        
    
    res = pd.DataFrame(res, columns=['dataset', 'feat_selection', 'loss_key', 'group', 'metric', 'value', 'model_path', 'fold_key'])
    res.to_csv(scores_path)

    df.append(res)
# Out:
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e10/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e10/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e10/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e10/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e10/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e10/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e10/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e10/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e10/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e10/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e10/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e10/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e10/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e10/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e10/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e10/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e10/bce/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e10/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e10/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e10/bce/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e10/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e10/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e10/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e10/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e10/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e10/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e10/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e10/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e10/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e10/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e10/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e10/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e10/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e10/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e10/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e10/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e10/bce/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e10/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e10/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e10/bce/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e50/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e50/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e50/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e50/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e50/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e50/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e50/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e50/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e50/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e50/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e50/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e50/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e50/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e50/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e50/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e50/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e50/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs500_e50/bce/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs1000_e10/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs1000_e10/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs1000_e10/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs1000_e10/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs1000_e10/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs1000_e10/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs1000_e10/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs1000_e10/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs1000_e10/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs1000_e10/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs1000_e10/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs1000_e10/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs1000_e10/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs1000_e10/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs1000_e10/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs1000_e10/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs1000_e10/bce/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs1000_e10/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs1000_e10/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs1000_e10/bce/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs2000_e10/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs2000_e10/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs2000_e10/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs2000_e10/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs2000_e10/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs2000_e10/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs2000_e10/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs2000_e10/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs2000_e10/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs2000_e10/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs2000_e10/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs2000_e10/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs2000_e10/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs2000_e10/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs2000_e10/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs2000_e10/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs2000_e10/bce/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs2000_e10/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs2000_e10/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs2000_e10/bce/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e50/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e50/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e50/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e50/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e50/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e50/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e50/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e50/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e50/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e50/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e50/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e50/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e50/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e50/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e50/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e50/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e50/bce/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e50/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e50/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/random/scbasset_output/obs100_e50/bce/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs100_e10/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs100_e10/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs100_e10/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs100_e10/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs100_e10/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs100_e10/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs100_e10/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs100_e10/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs100_e10/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs100_e10/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs100_e10/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs100_e10/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs100_e10/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs100_e10/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs100_e10/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs100_e10/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs100_e10/bce/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs100_e10/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs100_e10/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs100_e10/bce/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs500_e10/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs500_e10/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs500_e10/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs500_e10/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs500_e10/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs500_e10/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs500_e10/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs500_e10/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs500_e10/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs500_e10/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs500_e10/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs500_e10/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs500_e10/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs500_e10/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs500_e10/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs500_e10/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs500_e10/bce/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs500_e10/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs500_e10/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs500_e10/bce/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs1000_e10/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs1000_e10/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs1000_e10/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs1000_e10/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs1000_e10/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs1000_e10/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs1000_e10/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs1000_e10/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs1000_e10/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs1000_e10/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs1000_e10/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs1000_e10/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs1000_e10/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs1000_e10/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs1000_e10/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs1000_e10/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs1000_e10/bce/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs1000_e10/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs1000_e10/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs1000_e10/bce/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/poisson/fold_4/best_model.h5
# False /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/poisson/fold_4/best_model_scores.csv
# obs2000 pbmc episcanpy poisson
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/poisson/fold_4/../../../../scbasset_input/obs2000/fold_4/ad.h5ad
# WARNING:tensorflow:From /home/ilibarra/miniconda3/envs/scbasset/lib/python3.7/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# 2024-06-14 09:59:16.390979: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-06-14 09:59:16.391118: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-06-14 09:59:16.391144: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2024-06-14 09:59:16.391161: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2024-06-14 09:59:16.391177: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2024-06-14 09:59:16.391192: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2024-06-14 09:59:16.391207: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2024-06-14 09:59:16.391222: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2024-06-14 09:59:16.391237: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2024-06-14 09:59:16.391241: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2024-06-14 09:59:16.391401: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# get sequences scores
# 47/47 [==============================] - 14s 302ms/step
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/bce/fold_4/best_model.h5
# False /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/bce/fold_4/best_model_scores.csv
# obs2000 pbmc episcanpy bce
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/bce/fold_4/../../../../scbasset_input/obs2000/fold_4/ad.h5ad
# get sequences scores
# 47/47 [==============================] - 14s 293ms/step
# /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/bce/fold_3/best_model.h5
# False /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/bce/fold_3/best_model_scores.csv
# obs2000 pbmc episcanpy bce
# True /home/ilibarra/workspace/theislab/mubind/data/pbmc/episcanpy/scbasset_output/obs2000_e10/bce/fold_3/../../../../scbasset_input/obs2000/fold_3/ad.h5ad
# get sequences scores
# 47/47 [==============================] - 14s 301ms/step
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs100_e10/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs100_e10/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs100_e10/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs100_e10/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs100_e10/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs100_e10/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs100_e10/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs100_e10/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs100_e10/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs100_e10/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs100_e10/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs100_e10/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs100_e10/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs100_e10/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs100_e10/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs100_e10/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs100_e10/bce/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs100_e10/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs100_e10/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs100_e10/bce/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs200_e10/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs200_e10/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs200_e10/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs200_e10/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs200_e10/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs200_e10/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs200_e10/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs200_e10/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs200_e10/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs200_e10/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs200_e10/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs200_e10/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs200_e10/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs200_e10/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs200_e10/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs200_e10/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs200_e10/bce/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs200_e10/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs200_e10/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs200_e10/bce/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs500_e10/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs500_e10/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs500_e10/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs500_e10/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs500_e10/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs500_e10/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs500_e10/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs500_e10/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs500_e10/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs500_e10/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs500_e10/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs500_e10/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs500_e10/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs500_e10/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs500_e10/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs500_e10/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs500_e10/bce/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs500_e10/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs500_e10/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs500_e10/bce/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs1000_e10/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs1000_e10/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs1000_e10/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs1000_e10/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs1000_e10/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs1000_e10/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs1000_e10/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs1000_e10/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs1000_e10/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs1000_e10/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs1000_e10/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs1000_e10/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs1000_e10/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs1000_e10/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs1000_e10/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs1000_e10/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs1000_e10/bce/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs1000_e10/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs1000_e10/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs1000_e10/bce/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs2000_e10/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs2000_e10/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs2000_e10/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs2000_e10/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs2000_e10/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs2000_e10/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs2000_e10/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs2000_e10/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs2000_e10/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs2000_e10/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs2000_e10/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs2000_e10/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs2000_e10/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs2000_e10/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs2000_e10/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs2000_e10/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs2000_e10/bce/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs2000_e10/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs2000_e10/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/random/scbasset_output/obs2000_e10/bce/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs100_e10/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs100_e10/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs100_e10/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs100_e10/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs100_e10/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs100_e10/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs100_e10/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs100_e10/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs100_e10/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs100_e10/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs100_e10/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs100_e10/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs100_e10/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs100_e10/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs100_e10/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs100_e10/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs100_e10/bce/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs100_e10/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs100_e10/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs100_e10/bce/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs200_e10/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs200_e10/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs200_e10/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs200_e10/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs200_e10/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs200_e10/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs200_e10/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs200_e10/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs200_e10/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs200_e10/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs200_e10/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs200_e10/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs200_e10/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs200_e10/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs200_e10/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs200_e10/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs200_e10/bce/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs200_e10/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs200_e10/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs200_e10/bce/fold_3/best_model_scores.csv
# ...
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs1000_e10/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs1000_e10/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs1000_e10/bce/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs2000_e10/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs2000_e10/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs2000_e10/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs2000_e10/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs2000_e10/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs2000_e10/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs2000_e10/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs2000_e10/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs2000_e10/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs2000_e10/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs2000_e10/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs2000_e10/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs2000_e10/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs2000_e10/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs2000_e10/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs2000_e10/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs2000_e10/bce/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs2000_e10/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs2000_e10/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/pancreatic_endocrinogenesis/episcanpy/scbasset_output/obs2000_e10/bce/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs500_e10/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs500_e10/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs500_e10/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs500_e10/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs500_e10/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs500_e10/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs500_e10/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs500_e10/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs500_e10/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs500_e10/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs500_e10/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs500_e10/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs500_e10/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs500_e10/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs500_e10/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs500_e10/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs500_e10/bce/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs500_e10/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs500_e10/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs500_e10/bce/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs1000_e10/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs1000_e10/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs1000_e10/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs1000_e10/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs1000_e10/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs1000_e10/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs1000_e10/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs1000_e10/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs1000_e10/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs1000_e10/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs1000_e10/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs1000_e10/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs1000_e10/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs1000_e10/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs1000_e10/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs1000_e10/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs1000_e10/bce/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs1000_e10/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs1000_e10/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs1000_e10/bce/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs2000_e10/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs2000_e10/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs2000_e10/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs2000_e10/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs2000_e10/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs2000_e10/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs2000_e10/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs2000_e10/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs2000_e10/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs2000_e10/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs2000_e10/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs2000_e10/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs2000_e10/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs2000_e10/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs2000_e10/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs2000_e10/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs2000_e10/bce/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs2000_e10/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs2000_e10/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/random/scbasset_output/obs2000_e10/bce/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs1000_e10/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs1000_e10/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs1000_e10/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs1000_e10/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs1000_e10/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs1000_e10/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs1000_e10/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs1000_e10/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs1000_e10/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs1000_e10/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs1000_e10/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs1000_e10/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs1000_e10/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs1000_e10/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs1000_e10/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs1000_e10/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs1000_e10/bce/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs1000_e10/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs1000_e10/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs1000_e10/bce/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs2000_e10/poisson/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs2000_e10/poisson/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs2000_e10/poisson/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs2000_e10/poisson/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs2000_e10/poisson/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs2000_e10/poisson/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs2000_e10/poisson/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs2000_e10/poisson/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs2000_e10/poisson/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs2000_e10/poisson/fold_3/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs2000_e10/bce/fold_0/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs2000_e10/bce/fold_0/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs2000_e10/bce/fold_1/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs2000_e10/bce/fold_1/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs2000_e10/bce/fold_2/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs2000_e10/bce/fold_2/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs2000_e10/bce/fold_4/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs2000_e10/bce/fold_4/best_model_scores.csv
# /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs2000_e10/bce/fold_3/best_model.h5
# True /home/ilibarra/workspace/theislab/mubind/data/noack_2022/episcanpy/scbasset_output/obs2000_e10/bce/fold_3/best_model_scores.csv

# %%
res = pd.concat(df)
res['model'] = 'scBasset'
print('')

# %%
res['n_epochs'] = res['model_path'].str.split('/').str[-4].str.split('_').str[1].str[1:].astype(int)
res
# Out:
#        dataset feat_selection loss_key  group         metric     value  \
# 0         pbmc         random  poisson  train        roc_auc  0.636187
# 1         pbmc         random  poisson  train  roc_auc_multi  0.525161
# 2         pbmc         random  poisson  train         pr_auc  0.107659
# 3         pbmc         random  poisson  train   pr_auc_multi  0.077117
# 4         pbmc         random  poisson  train             r2 -0.121580
# ..         ...            ...      ...    ...            ...       ...
# 10  noack_2022      episcanpy      bce   test        roc_auc  0.661295
# 11  noack_2022      episcanpy      bce   test  roc_auc_multi  0.500000
# 12  noack_2022      episcanpy      bce   test         pr_auc  0.014053
# 13  noack_2022      episcanpy      bce   test   pr_auc_multi  0.002838
# 14  noack_2022      episcanpy      bce   test             r2  0.005106
#
#                                            model_path fold_key n_obs  \
# 0   /home/ilibarra/workspace/theislab/mubind/data/...   fold_0   100
# 1   /home/ilibarra/workspace/theislab/mubind/data/...   fold_0   100
# 2   /home/ilibarra/workspace/theislab/mubind/data/...   fold_0   100
# 3   /home/ilibarra/workspace/theislab/mubind/data/...   fold_0   100
# 4   /home/ilibarra/workspace/theislab/mubind/data/...   fold_0   100
# ..                                                ...      ...   ...
# 10  /home/ilibarra/workspace/theislab/mubind/data/...   fold_3  2000
# 11  /home/ilibarra/workspace/theislab/mubind/data/...   fold_3  2000
# 12  /home/ilibarra/workspace/theislab/mubind/data/...   fold_3  2000
# 13  /home/ilibarra/workspace/theislab/mubind/data/...   fold_3  2000
# 14  /home/ilibarra/workspace/theislab/mubind/data/...   fold_3  2000
#
#           time     model  n_epochs
# 0    30.751385  scBasset        10
# 1    30.751385  scBasset        10
# 2    30.751385  scBasset        10
# 3    30.751385  scBasset        10
# 4    30.751385  scBasset        10
# ..         ...       ...       ...
# 10  532.165629  scBasset        10
# 11  532.165629  scBasset        10
# 12  532.165629  scBasset        10
# 13  532.165629  scBasset        10
# 14  532.165629  scBasset        10
#
# [3735 rows x 12 columns]

# %%
res.to_csv('results_scbasset.csv')

# %%
res['dataset'].value_counts()
# Out:
# pancreatic_endocrinogenesis    1500
# pbmc                           1440
# noack_2022                      750
# Name: dataset, dtype: int64
